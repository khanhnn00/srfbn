# %%
cd /content/drive/My Drive/ColabNotebooks/srfbn
# Out:
# /content/drive/My Drive/ColabNotebooks/srfbn

# %%
import cv2
import matplotlib.pyplot as plt
import os
import os.path as osp
import numpy as np

# %%
# !python train.py -opt options/train/train_SRFBN_example.json
# Out:
# ===> Export CUDA_VISIBLE_DEVICES = [0]
# [Warning] Path [experiments/SRFBN_in3f32_x4] already exists. Rename it to [experiments/SRFBN_in3f32_x4_archived_201225-062019]
# ===> Experimental DIR: [experiments/SRFBN_in3f32_x4]
# ===> Random Seed: [0]
# ===> Binary files already exists in [../Dataset/DIV2K/DIV2K_train_HR/result/HR_x4_npy]. Skip binary files generation.
# ===> Binary files already exists in [../Dataset/DIV2K/DIV2K_train_HR/result/LR_x4_npy]. Skip binary files generation.
# ===> [LRHR] Dataset is created.
# ===> Train Dataset: DIV2K   Number of images: [16000]
# ===> [LRHR] Dataset is created.
# ===> Val Dataset: Set5   Number of images: [5]
# ===> Building network [SRFBN]...
# ==> Initializing the network using [kaiming]
# initialization method [kaiming]
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [ConvTranspose2d] ...
# initializing [ConvTranspose2d] ...
# initializing [ConvTranspose2d] ...
# initializing [ConvTranspose2d] ...
# initializing [ConvTranspose2d] ...
# initializing [ConvTranspose2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [Conv2d] ...
# initializing [ConvTranspose2d] ...
# initializing [Conv2d] ...
# ==================================================
# ===> Network Summary
#
# SRFBN(
#   (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (conv_in): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): PReLU(num_parameters=1)
#   )
#   (feat_in): Sequential(
#     (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#     (1): PReLU(num_parameters=1)
#   )
#   (block): FeedbackBlock(
#     (compress_in): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): PReLU(num_parameters=1)
#     )
#     (upBlocks): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (3): Sequential(
#         (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (4): Sequential(
#         (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (5): Sequential(
#         (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (downBlocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (1): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (3): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (4): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#       (5): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (uptranBlocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (1): Sequential(
#         (0): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (2): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (3): Sequential(
#         (0): Conv2d(160, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (4): Sequential(
#         (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (downtranBlocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (1): Sequential(
#         (0): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (2): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (3): Sequential(
#         (0): Conv2d(160, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#       (4): Sequential(
#         (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (compress_out): Sequential(
#       (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): PReLU(num_parameters=1)
#     )
#   )
#   (out): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#     (1): PReLU(num_parameters=1)
#   )
#   (conv_out): Sequential(
#     (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
# )
#
# Network structure: [DataParallel - SRFBN], with parameters: [910,550]
# ==================================================
# ===> Solver Initialized : [SRSolver] || Use CL : [True] || Use GPU : [True]
# optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0001
#     lr: 0.0001
#     weight_decay: 0
# )
# lr_scheduler milestones: Counter({200: 1, 400: 1, 600: 1, 800: 1})   gamma: 0.500000
# ===> Start Train
# ==================================================
# Method: SRFBN || Scale: 4 || Epoch Range: (1 ~ 400)
#
# ===> Training Epoch: [1/400]...  Learning Rate: 0.000100
# Epoch: [1/400]:   4% 44/1000 [06:24<1:14:00,  4.64s/it, Batch Loss: 34.3195]
